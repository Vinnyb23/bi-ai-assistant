# %% [markdown]
# # Phase 1 Exploration -- BI AI Assistant
#
# Week 1-2 scratchpad: explore the synthetic sales data, sanity-check trends/seasonality, and prototype forecast features before they get promoted into `src/`.
#
# Run `python ../src/data_prep.py` first if `../data/bi_assistant.db` does not exist yet.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

import pandas as pd
import matplotlib.pyplot as plt

from src.forecast import load_daily_sales, add_features

daily = load_daily_sales()
daily.tail()

# %%
fig, ax = plt.subplots(figsize=(12, 4))
daily.set_index('order_date')['total_sales'].plot(ax=ax, title='Daily total sales')
plt.show()

# %%
features = add_features(daily)
features.describe()

# %% [markdown]
# ## Notes / Learning Log
#
# - Week 1: ...
# - Week 2: ...
